# %% [markdown]
# # **Introduction to Modern Statistics**
# ## Chapter 2: Study Design

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **My Solution:**
#
# 2.1.a.
# - population mean = 52
# - sample mean = 58
#
# Reason: At the beggining of the paragraph it says that all American households spent an average of about $52.  Whereas in 2008 there was just a survey, so it has to be from just a sample of the population, also includes just 1500 households.
#
# 2.1.b.
# - population mean = 3.37
# - sample mean = 3.59
#
# Reason: The first line of the paragraph does not tell about restrictions related to the population target, but the survey has a restriction to just 203 students.
#
# **Book solution:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **My Solution:**
#
# a. Population of interest: All pregnant woman during 1989 and 1993 (**All pregnant woman != All births**)
#
# b. The results cannot be generalized to the population because we cannot determine if this selection was random, and also the pollution is just of Southern California. Also, during the time of the study, there should be a lot more births than the reported, so we cannot generalized. Also, as they cannot control the confounding variables (was only an observational study), we cannot establish causal relationship
#
# **Book Solution:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
